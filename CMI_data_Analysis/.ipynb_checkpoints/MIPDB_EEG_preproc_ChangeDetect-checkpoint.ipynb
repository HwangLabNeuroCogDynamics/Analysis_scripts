# %%
import mne
from mne.datasets import sample
from mne import io
from mne.preprocessing import create_ecg_epochs, create_eog_epochs
from mne.preprocessing import ICA
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import fnmatch

# %%
ROOT = '/home/dcellier/RDSS/CMI_data/MIPDB/EEGData/'

# %%
all_sub_events={}
rep_subs={}
for f in os.listdir(ROOT):
    if f=='channel_locs.txt' or f=='subs_without_EEG' or f=='EEG paradigm info Misc_Readme' or f=='subs_w_2_RS_EEG':
        print('nothin')
    else:
        thisfpath=ROOT+f+'/EEG/raw/csv_format/'
        for raw_dat in os.listdir(thisfpath):
            
            #print(thisfpath)
            pattern='%s00*_events.csv' %f
            pattern2='%s 00*_events.csv' %f
            pattern3='%s_part*00*_events.csv'%f
            if (fnmatch.fnmatch(raw_dat, pattern)) or (fnmatch.fnmatch(raw_dat, pattern2)) or (fnmatch.fnmatch(raw_dat, pattern3)):
                print(raw_dat)
                thisTrigfile=pd.read_csv(thisfpath+raw_dat)
                not_CD=0
                ev_ar=[]
                for n in range(len(thisTrigfile['type'])):
                    trig=thisTrigfile['type'][n]
                    time_stamp=thisTrigfile['latency'][n]
                    if trig != 'type':
                        if int(trig) not in [94,95,96,5,8,9,12,13]:
                            not_CD=1
                            #print(trig)
                        else:
                            ev_ar.append([int(time_stamp),0,int(trig)])
                if not_CD==0 and (f not in all_sub_events.keys()):
                    print("YESSSSSSSSSs")
                    all_sub_events[f]=[]
                if not_CD==0 and (len(all_sub_events[f])<3):
                    print('adding one file')
                    all_sub_events[f].append({raw_dat:ev_ar})
                elif not_CD==0 and (len(all_sub_events[f])>3):
                    print('AHHHHHHHHHHHHHHHH   '+f)
                    rep_subs[f]=ev_ar
                #elif not_CD==1:
                 #   print(raw_dat)
# Out:
# nothin
# A00053440001_events.csv
# A00053440002_events.csv
# A00053440003_events.csv
# A00053440004_events.csv
# A00053440005_events.csv
# YESSSSSSSSSs
# adding one file
# A00053440006_events.csv
# A00053440_part2001_events.csv
# adding one file
# A00053440_part2002_events.csv
# A00053440_part2003_events.csv
# adding one file
# A00053440_part2004_events.csv
# A00053440_part2005_events.csv
# nothin
# nothin
# nothin
# A00059578001_events.csv
# A00059578002_events.csv
# A00059578003_events.csv
# A00059578004_events.csv
# YESSSSSSSSSs
# adding one file
# A00059578005_events.csv
# A00059578006_events.csv
# adding one file
# A00059578007_events.csv
# A00059578008_events.csv
# adding one file
# A00059578009_events.csv
# A00055628002_events.csv
# A00055628003_events.csv
# A00055628004_events.csv
# A00055628005_events.csv
# A00055628006_events.csv
# YESSSSSSSSSs
# adding one file
# A00055628007_events.csv
# A00055628008_events.csv
# adding one file
# A00055628009_events.csv
# A00062919 001_events.csv
# A00062919 002_events.csv
# A00062919 003_events.csv
# A00062919 004_events.csv
# A00062919 005_events.csv
# YESSSSSSSSSs
# adding one file
# A00062919 006_events.csv
# A00062919 007_events.csv
# A00062919 008_events.csv
# A00062919 009_events.csv
# adding one file
# A00063051 001_events.csv
# A00063051 002_events.csv
# A00063051 003_events.csv
# A00063051 004_events.csv
# A00063051 005_events.csv
# YESSSSSSSSSs
# adding one file
# A00063051 006_events.csv
# A00063051 007_events.csv
# A00063051 008_events.csv
# adding one file
# A00063051 009_events.csv
# A00063117 001_events.csv
# A00063117 002_events.csv
# A00063117 003_events.csv
# A00063117 004_events.csv
# A00063117 005_events.csv
# YESSSSSSSSSs
# adding one file
# A00063117 006_events.csv
# A00063117 007_events.csv
# A00063117 008_events.csv
# adding one file
# A00063117 009_events.csv
# A00051955001_events.csv
# A00051955002_events.csv
# A00051955003_events.csv
# A00051955004_events.csv
# A00051955005_events.csv
# YESSSSSSSSSs
# adding one file
# A00051955006_events.csv
# A00051955007_events.csv
# adding one file
# A00051955008_events.csv
# A00051955009_events.csv
# adding one file
# A00053597001_events.csv
# A00053597002_events.csv
# A00053597003_events.csv
# A00053597004_events.csv
# A00053597005_events.csv
# YESSSSSSSSSs
# adding one file
# A00053597006_events.csv
# A00053597007_events.csv
# adding one file
# A00053597008_events.csv
# A00053597009_events.csv
# adding one file
# A00053909001_events.csv
# A00053909002_events.csv
# A00053909003_events.csv
# A00053909004_events.csv
# A00053909005_events.csv
# YESSSSSSSSSs
# adding one file
# A00053909006_events.csv
# A00053909007_events.csv
# adding one file
# A00053909008_events.csv
# A00053909009_events.csv
# adding one file
# A00053990001_events.csv
# A00053990002_events.csv
# A00053990003_events.csv
# A00053990004_events.csv
# A00053990005_events.csv
# A00053990006_events.csv
# A00053990007_events.csv
# A00053990008_events.csv
# YESSSSSSSSSs
# adding one file
# A00053990009_events.csv
# adding one file
# A00054023001_events.csv
# A00054023002_events.csv
# A00054023003_events.csv
# A00054023004_events.csv
# A00054023005_events.csv
# A00054023006_events.csv
# YESSSSSSSSSs
# adding one file
# A00054023007_events.csv
# A00054023008_events.csv
# adding one file
# A00054023009_events.csv
# A00054039001_events.csv
# A00054039002_events.csv
# A00054039003_events.csv
# A00054039004_events.csv
# A00054039005_events.csv
# YESSSSSSSSSs
# adding one file
# A00054039006_events.csv
# A00054039007_events.csv
# adding one file
# A00054039008_events.csv
# A00054039009_events.csv
# adding one file
# A00054207001_events.csv
# A00054207002_events.csv
# A00054207003_events.csv
# A00054207004_events.csv
# A00054207005_events.csv
# YESSSSSSSSSs
# adding one file
# A00054207006_events.csv
# A00054207007_events.csv
# adding one file
# A00054207008_events.csv
# A00054207009_events.csv
# adding one file
# A00054239001_events.csv
# A00054239002_events.csv
# A00054239003_events.csv
# A00054239004_events.csv
# A00054239005_events.csv
# YESSSSSSSSSs
# adding one file
# A00054239006_events.csv
# A00054239007_events.csv
# adding one file
# A00054239008_events.csv
# A00054239009_events.csv
# adding one file
# A00054287001_events.csv
# A00054287002_events.csv
# A00054287003_events.csv
# A00054287004_events.csv
# A00054287005_events.csv
# YESSSSSSSSSs
# adding one file
# A00054287006_events.csv
# A00054287007_events.csv
# adding one file
# A00054287008_events.csv
# A00054287009_events.csv
# adding one file
# A00054359001_events.csv
# A00054359002_events.csv
# A00054359004_events.csv
# A00054359006_events.csv
# A00054359007_events.csv
# YESSSSSSSSSs
# adding one file
# A00054359008_events.csv
# A00054359009_events.csv
# adding one file
# A00054369001_events.csv
# A00054369002_events.csv
# A00054369003_events.csv
# A00054369004_events.csv
# A00054369005_events.csv
# YESSSSSSSSSs
# adding one file
# A00054369006_events.csv
# A00054369007_events.csv
# adding one file
# A00054369008_events.csv
# A00054369009_events.csv
# adding one file
# A00054387001_events.csv
# A00054387002_events.csv
# A00054387003_events.csv
# A00054387004_events.csv
# A00054387005_events.csv
# YESSSSSSSSSs
# adding one file
# A00054387006_events.csv
# A00054387007_events.csv
# adding one file
# A00054387008_events.csv
# A00054387009_events.csv
# adding one file
# A00054400001_events.csv
# A00054400002_events.csv
# A00054400003_events.csv
# A00054400004_events.csv
# A00054400005_events.csv
# YESSSSSSSSSs
# adding one file
# A00054400006_events.csv
# A00054400007_events.csv
# adding one file
# A00054400008_events.csv
# A00054400009_events.csv
# adding one file
# A00054417001_events.csv
# A00054417002_events.csv
# A00054417003_events.csv
# A00054417004_events.csv
# A00054417005_events.csv
# YESSSSSSSSSs
# adding one file
# A00054417006_events.csv
# A00054417007_events.csv
# adding one file
# A00054417008_events.csv
# A00054417009_events.csv
# adding one file
# A00054432001_events.csv
# A00054432002_events.csv
# A00054432003_events.csv
# A00054432004_events.csv
# A00054469001_events.csv
# A00054469002_events.csv
# A00054469003_events.csv
# A00054469004_events.csv
# YESSSSSSSSSs
# adding one file
# A00054469005_events.csv
# A00054469006_events.csv
# adding one file
# A00054469007_events.csv
# A00054469008_events.csv
# adding one file
# A00054469009_events.csv
# A00054517001_events.csv
# A00054517002_events.csv
# A00054517003_events.csv
# A00054517004_events.csv
# A00054517005_events.csv
# YESSSSSSSSSs
# adding one file
# A00054517006_events.csv
# A00054517007_events.csv
# adding one file
# A00054517008_events.csv
# adding one file
# A00054517009_events.csv
# A00054597001_events.csv
# A00054597002_events.csv
# A00054597003_events.csv
# A00054597004_events.csv
# A00054597005_events.csv
# YESSSSSSSSSs
# adding one file
# A00054597006_events.csv
# A00054597007_events.csv
# adding one file
# A00054597008_events.csv
# A00054597009_events.csv
# adding one file
# A00054623001_events.csv
# A00054623002_events.csv
# A00054623003_events.csv
# A00054623004_events.csv
# A00054623005_events.csv
# YESSSSSSSSSs
# adding one file
# A00054623006_events.csv
# A00054623007_events.csv
# adding one file
# A00054623008_events.csv
# A00054623009_events.csv
# adding one file
# A00054647001_events.csv
# A00054647002_events.csv
# A00054647003_events.csv
# A00054647004_events.csv
# A00054647005_events.csv
# YESSSSSSSSSs
# adding one file
# A00054647006_events.csv
# A00054647007_events.csv
# adding one file
# A00054647008_events.csv
# A00054647009_events.csv
# adding one file
# A00054666001_events.csv
# A00054666002_events.csv
# A00054666003_events.csv
# A00054666004_events.csv
# A00054666005_events.csv
# YESSSSSSSSSs
# adding one file
# A00054666006_events.csv
# A00054666007_events.csv
# adding one file
# A00054666008_events.csv
# A00054666009_events.csv
# adding one file
# A00054694001_events.csv
# A00054694002_events.csv
# A00054694003_events.csv
# A00054694004_events.csv
# A00054694005_events.csv
# YESSSSSSSSSs
# adding one file
# A00054694006_events.csv
# A00054694007_events.csv
# adding one file
# A00054694008_events.csv
# A00054694009_events.csv
# adding one file
# A00054721001_events.csv
# A00054721002_events.csv
# A00054721003_events.csv
# A00054721004_events.csv
# YESSSSSSSSSs
# adding one file
# A00054721005_events.csv
# A00054721006_events.csv
# adding one file
# A00054721007_events.csv
# A00054721008_events.csv
# adding one file
# A00054721009_events.csv
# A00054743001_events.csv
# A00054743002_events.csv
# A00054743003_events.csv
# A00054743004_events.csv
# A00054743005_events.csv
# YESSSSSSSSSs
# adding one file
# A00054743006_events.csv
# A00054743007_events.csv
# adding one file
# A00054743008_events.csv
# A00054743009_events.csv
# adding one file
# A00054753001_events.csv
# A00054753002_events.csv
# A00054753003_events.csv
# A00054753004_events.csv
# YESSSSSSSSSs
# adding one file
# A00054753005_events.csv
# A00054753006_events.csv
# adding one file
# A00054753007_events.csv
# A00054753008_events.csv
# adding one file
# A00054753009_events.csv
# A00054766001_events.csv
# A00054766002_events.csv
# A00054766003_events.csv
# A00054766004_events.csv
# A00054766005_events.csv
# YESSSSSSSSSs
# adding one file
# A00054766006_events.csv
# A00054766007_events.csv
# adding one file
# A00054766008_events.csv
# A00054766009_events.csv
# adding one file
# A00054817001_events.csv
# A00054817002_events.csv
# A00054817003_events.csv
# A00054817004_events.csv
# A00054817005_events.csv
# YESSSSSSSSSs
# adding one file
# A00054817006_events.csv
# A00054817007_events.csv
# adding one file
# A00054817008_events.csv
# A00054817009_events.csv
# adding one file
# A00054836001_events.csv
# A00054836002_events.csv
# A00054836003_events.csv
# A00054836004_events.csv
# A00054836005_events.csv
# YESSSSSSSSSs
# adding one file
# A00054836006_events.csv
# A00054836007_events.csv
# adding one file
# A00054836008_events.csv
# A00054836009_events.csv
# adding one file
# A00054894001_events.csv
# A00054894002_events.csv
# A00054894003_events.csv
# A00054894004_events.csv
# A00054894005_events.csv
# YESSSSSSSSSs
# adding one file
# A00054894006_events.csv
# A00054894007_events.csv
# adding one file
# A00054894008_events.csv
# A00054894009_events.csv
# adding one file
# A00054923001_events.csv
# A00054923002_events.csv
# A00054923003_events.csv
# A00054923004_events.csv
# A00054923005_events.csv
# YESSSSSSSSSs
# adding one file
# A00054923006_events.csv
# A00054923007_events.csv
# adding one file
# A00054923008_events.csv
# A00054923009_events.csv
# adding one file
# A00054930001_events.csv
# A00054930002_events.csv
# A00054930003_events.csv
# A00054930004_events.csv
# A00054930005_events.csv
# YESSSSSSSSSs
# adding one file
# A00054930006_events.csv
# A00054930007_events.csv
# adding one file
# A00054930008_events.csv
# A00054930009_events.csv
# adding one file
# A00055024001_events.csv
# A00055024002_events.csv
# A00055024003_events.csv
# A00055024004_events.csv
# A00055024005_events.csv
# YESSSSSSSSSs
# adding one file
# A00055024006_events.csv
# A00055024007_events.csv
# adding one file
# A00055024008_events.csv
# A00055024009_events.csv
# adding one file
# A00055055001_events.csv
# A00055055002_events.csv
# A00055055003_events.csv
# A00055055004_events.csv
# A00055055005_events.csv
# YESSSSSSSSSs
# adding one file
# A00055055006_events.csv
# A00055055007_events.csv
# adding one file
# A00055055008_events.csv
# A00055055009_events.csv
# adding one file
# A00055065001_events.csv
# A00055065002_events.csv
# A00055065003_events.csv
# A00055065004_events.csv
# YESSSSSSSSSs
# adding one file
# A00055065005_events.csv
# A00055065006_events.csv
# adding one file
# A00055065007_events.csv
# A00055065008_events.csv
# adding one file
# A00055065009_events.csv
# A00055077001_events.csv
# A00055077002_events.csv
# A00055077003_events.csv
# A00055077004_events.csv
# A00055077005_events.csv
# YESSSSSSSSSs
# adding one file
# A00055077006_events.csv
# A00055077007_events.csv
# adding one file
# A00055077008_events.csv
# A00055077009_events.csv
# adding one file
# A00055085001_events.csv
# A00055085002_events.csv
# A00055085003_events.csv
# A00055085004_events.csv
# A00055085005_events.csv
# YESSSSSSSSSs
# adding one file
# A00055085006_events.csv
# A00055085007_events.csv
# adding one file
# A00055085008_events.csv
# A00055085009_events.csv
# adding one file
# A00055103001_events.csv
# A00055103002_events.csv
# A00055103003_events.csv
# A00055103004_events.csv
# A00055103005_events.csv
# YESSSSSSSSSs
# adding one file
# A00055103006_events.csv
# A00055103007_events.csv
# adding one file
# A00055103008_events.csv
# A00055103009_events.csv
# A00055296001_events.csv
# A00055296002_events.csv
# A00055296003_events.csv
# A00055296004_events.csv
# A00055296005_events.csv
# YESSSSSSSSSs
# adding one file
# A00055296006_events.csv
# A00055296007_events.csv
# adding one file
# A00055296008_events.csv
# A00055296009_events.csv
# A00055392001_events.csv
# A00055392002_events.csv
# A00055392003_events.csv
# A00055392004_events.csv
# A00055392005_events.csv
# YESSSSSSSSSs
# adding one file
# A00055392006_events.csv
# A00055392007_events.csv
# adding one file
# A00055392008_events.csv
# A00055392009_events.csv
# adding one file
# A00055424001_events.csv
# A00055424002_events.csv
# A00055424003_events.csv
# A00055424004_events.csv
# A00055424005_events.csv
# YESSSSSSSSSs
# adding one file
# A00055424006_events.csv
# A00055424007_events.csv
# adding one file
# A00055424008_events.csv
# A00055424009_events.csv
# adding one file
# A00055429001_events.csv
# A00055429002_events.csv
# A00055429003_events.csv
# A00055429004_events.csv
# A00055429005_events.csv
# YESSSSSSSSSs
# adding one file
# A00055429006_events.csv
# A00055429007_events.csv
# adding one file
# A00055429008_events.csv
# A00055429009_events.csv
# adding one file
# A00055486001_events.csv
# A00055486002_events.csv
# A00055486003_events.csv
# A00055486004_events.csv
# A00055486005_events.csv
# YESSSSSSSSSs
# adding one file
# A00055486006_events.csv
# A00055486007_events.csv
# adding one file
# A00055486008_events.csv
# adding one file
# A00055486009_events.csv
# A00055613001_events.csv
# A00055613002_events.csv
# A00055613003_events.csv
# A00055613004_events.csv
# A00055613005_events.csv
# YESSSSSSSSSs
# adding one file
# A00055613006_events.csv
# A00055613007_events.csv
# adding one file
# A00055613008_events.csv
# A00055613009_events.csv
# adding one file
# A00055649001_events.csv
# A00055649002_events.csv
# A00055649003_events.csv
# A00055649004_events.csv
# A00055649005_events.csv
# YESSSSSSSSSs
# adding one file
# A00055649006_events.csv
# A00055649007_events.csv
# adding one file
# A00055649008_events.csv
# A00055649009_events.csv
# adding one file
# A00055662001_events.csv
# A00055662002_events.csv
# A00055662003_events.csv
# A00055662004_events.csv
# A00055662005_events.csv
# YESSSSSSSSSs
# adding one file
# A00055662006_events.csv
# A00055662007_events.csv
# adding one file
# A00055662008_events.csv
# A00055662009_events.csv
# adding one file
# A00055682001_events.csv
# A00055682002_events.csv
# A00055682003_events.csv
# A00055682004_events.csv
# A00055682005_events.csv
# YESSSSSSSSSs
# adding one file
# A00055682006_events.csv
# A00055682007_events.csv
# adding one file
# A00055682008_events.csv
# A00055682009_events.csv
# adding one file
# A00055731001_events.csv
# A00055731002_events.csv
# A00055731003_events.csv
# A00055731004_events.csv
# A00055731005_events.csv
# YESSSSSSSSSs
# adding one file
# A00055731006_events.csv
# A00055731007_events.csv
# adding one file
# A00055731008_events.csv
# A00055731009_events.csv
# adding one file
# A00055745001_events.csv
# A00055745002_events.csv
# A00055745003_events.csv
# A00055745004_events.csv
# A00055745005_events.csv
# YESSSSSSSSSs
# adding one file
# A00055745006_events.csv
# A00055745007_events.csv
# adding one file
# A00055745008_events.csv
# A00055745009_events.csv
# adding one file
# A00055754001_events.csv
# A00055754002_events.csv
# A00055754003_events.csv
# A00055754004_events.csv
# A00055754005_events.csv
# A00055754006_events.csv
# A00055837001_events.csv
# A00055837002_events.csv
# A00055837003_events.csv
# A00055837004_events.csv
# A00055837005_events.csv
# YESSSSSSSSSs
# adding one file
# A00055837006_events.csv
# A00055837007_events.csv
# adding one file
# A00055837008_events.csv
# A00055837009_events.csv
# adding one file
# A00055865001_events.csv
# A00055865002_events.csv
# A00055865003_events.csv
# A00055865004_events.csv
# A00055865005_events.csv
# YESSSSSSSSSs
# adding one file
# A00055865006_events.csv
# A00055865007_events.csv
# adding one file
# A00055865008_events.csv
# A00055865009_events.csv
# adding one file
# A00055893001_events.csv
# A00055893002_events.csv
# A00055893003_events.csv
# A00055893004_events.csv
# A00055893005_events.csv
# YESSSSSSSSSs
# adding one file
# A00055893006_events.csv
# A00055893007_events.csv
# adding one file
# A00055893008_events.csv
# A00055893009_events.csv
# adding one file
# A00055910001_events.csv
# A00055910002_events.csv
# A00055910003_events.csv
# A00055910004_events.csv
# A00055910005_events.csv
# YESSSSSSSSSs
# adding one file
# A00055910006_events.csv
# A00055910007_events.csv
# adding one file
# A00055910008_events.csv
# A00055910009_events.csv
# adding one file
# A00055956001_events.csv
# A00055956002_events.csv
# A00055956003_events.csv
# A00055956004_events.csv
# A00055956005_events.csv
# YESSSSSSSSSs
# adding one file
# A00055956006_events.csv
# A00055956007_events.csv
# adding one file
# A00055956008_events.csv
# adding one file
# A00055956009_events.csv
# A00056002001_events.csv
# A00056002002_events.csv
# A00056002003_events.csv
# A00056002004_events.csv
# A00056002005_events.csv
# YESSSSSSSSSs
# adding one file
# A00056002006_events.csv
# A00056002007_events.csv
# adding one file
# A00056002008_events.csv
# A00056002009_events.csv
# adding one file
# A00056054001_events.csv
# A00056054002_events.csv
# A00056054003_events.csv
# A00056054004_events.csv
# A00056054005_events.csv
# YESSSSSSSSSs
# adding one file
# A00056054006_events.csv
# A00056054007_events.csv
# adding one file
# A00056054008_events.csv
# A00056054009_events.csv
# adding one file
# A00056116001_events.csv
# A00056116002_events.csv
# A00056116003_events.csv
# A00056116004_events.csv
# A00056116005_events.csv
# YESSSSSSSSSs
# adding one file
# A00056116006_events.csv
# A00056116008_events.csv
# adding one file
# A00056116009_events.csv
# A00056166001_events.csv
# A00056166002_events.csv
# A00056166003_events.csv
# A00056166004_events.csv
# A00056166005_events.csv
# YESSSSSSSSSs
# adding one file
# A00056166006_events.csv
# A00056166007_events.csv
# adding one file
# A00056166008_events.csv
# A00056166009_events.csv
# adding one file
# A00056257001_events.csv
# A00056257002_events.csv
# A00056257003_events.csv
# A00056257004_events.csv
# A00056257005_events.csv
# YESSSSSSSSSs
# adding one file
# A00056257006_events.csv
# A00056257007_events.csv
# adding one file
# A00056257008_events.csv
# A00056257009_events.csv
# adding one file
# A00056604001_events.csv
# A00056604002_events.csv
# A00056604003_events.csv
# A00056604004_events.csv
# A00056604005_events.csv
# A00056604006_events.csv
# YESSSSSSSSSs
# adding one file
# A00056604007_events.csv
# A00056604008_events.csv
# adding one file
# A00056604009_events.csv
# A00056693001_events.csv
# A00056693002_events.csv
# A00056693003_events.csv
# A00056693004_events.csv
# A00056693005_events.csv
# A00056693006_events.csv
# YESSSSSSSSSs
# adding one file
# A00056693007_events.csv
# A00056693008_events.csv
# adding one file
# A00056693009_events.csv
# A00056913001_events.csv
# A00056913002_events.csv
# A00056913003_events.csv
# A00056913004_events.csv
# A00056913005_events.csv
# A00056913006_events.csv
# YESSSSSSSSSs
# adding one file
# A00056913007_events.csv
# A00056913008_events.csv
# adding one file
# A00056913009_events.csv
# A00058596001_events.csv
# A00058596002_events.csv
# A00058596003_events.csv
# A00058596004_events.csv
# A00058596005_events.csv
# A00058775001_events.csv
# A00058775002_events.csv
# A00058775003_events.csv
# A00058775004_events.csv
# A00058775005_events.csv
# YESSSSSSSSSs
# adding one file
# A00058775006_events.csv
# A00058775007_events.csv
# adding one file
# A00058775008_events.csv
# A00058775009_events.csv
# A00059063001_events.csv
# A00059063002_events.csv
# A00059063003_events.csv
# A00059063004_events.csv
# A00059063005_events.csv
# YESSSSSSSSSs
# adding one file
# A00059063006_events.csv
# A00059063007_events.csv
# adding one file
# A00059063008_events.csv
# A00059063009_events.csv
# adding one file

# %%
#rep_subs.keys()
all_sub_events.keys()
# Out:
# dict_keys(['A00053440', 'A00059578', 'A00055628', 'A00062919', 'A00063051', 'A00063117', 'A00051955', 'A00053597', 'A00053909', 'A00053990', 'A00054023', 'A00054039', 'A00054207', 'A00054239', 'A00054287', 'A00054359', 'A00054369', 'A00054387', 'A00054400', 'A00054417', 'A00054469', 'A00054517', 'A00054597', 'A00054623', 'A00054647', 'A00054666', 'A00054694', 'A00054721', 'A00054743', 'A00054753', 'A00054766', 'A00054817', 'A00054836', 'A00054894', 'A00054923', 'A00054930', 'A00055024', 'A00055055', 'A00055065', 'A00055077', 'A00055085', 'A00055103', 'A00055296', 'A00055392', 'A00055424', 'A00055429', 'A00055486', 'A00055613', 'A00055649', 'A00055662', 'A00055682', 'A00055731', 'A00055745', 'A00055837', 'A00055865', 'A00055893', 'A00055910', 'A00055956', 'A00056002', 'A00056054', 'A00056116', 'A00056166', 'A00056257', 'A00056604', 'A00056693', 'A00056913', 'A00058775', 'A00059063'])

# %%
#ex_sub=pd.read_csv(ROOT+'A00063051/EEG/raw/csv_format/A00063051 005_events.csv')
#ex_sub2=pd.read_csv(ROOT+'A00063051/EEG/raw/csv_format/A00063051 008_events.csv')
#ex_sub

# %%
#ex_sub2

# %%
#sub.type[2]

# %%
raw=mne.io.read_raw_egi(ROOT+'A00053440/EEG/raw/raw_format/A00053440005.raw',montage=mne.channels.read_montage(kind='GSN-HydroCel-129'),preload=True, verbose=True)
# Out:
# Reading EGI header from /home/dcellier/RDSS/CMI_data/MIPDB/EEGData/A00053440/EEG/raw/raw_format/A00053440005.raw...
#     Reading events ...
#     Assembling measurement info ...
#     Synthesizing trigger channel "STI 014" ...
#     Excluding events {102 , 104 , 11  , 14  , 15  , 16  , 17  , 18  , 20  , 21  , 22  , 23  , 24  , 25  , 26  , 27  , 28  , 30  , 31  , 32  , 33  , 34  , 35  , 4   , 50  , 82  , 84  , 90  , 91  , 92  , 93  , 94  } ...
# Reading 0 ... 106802  =      0.000 ...   213.604 secs...
# <ipython-input-71-8e087ebbfdf1>:1: RuntimeWarning: The following EEG sensors did not have a position specified in the selected montage: ['E129']. Their position has been left untouched.
#   raw=mne.io.read_raw_egi(ROOT+'A00053440/EEG/raw/raw_format/A00053440005.raw',montage=mne.channels.read_montage(kind='GSN-HydroCel-129'),preload=True, verbose=True)

# %%
raw_evs=mne.find_events(raw)
raw_evs
# Out:
# 75 events found
# Event IDs: [1 2 3 4 5]
# array([[ 21816,      0,      3],
#        [ 24018,      0,      4],
#        [ 24672,      0,      1],
#        [ 25218,      0,      3],
#        [ 26617,      0,      5],
#        [ 27222,      0,      2],
#        [ 27819,      0,      3],
#        [ 29217,      0,      5],
#        [ 30007,      0,      2],
#        [ 30425,      0,      3],
#        [ 32627,      0,      5],
#        [ 33232,      0,      2],
#        [ 33829,      0,      3],
#        [ 35228,      0,      5],
#        [ 36123,      0,      2],
#        [ 36429,      0,      3],
#        [ 38292,      0,      1],
#        [ 39427,      0,      5],
#        [ 40207,      0,      2],
#        [ 40629,      0,      3],
#        [ 43627,      0,      4],
#        [ 44417,      0,      1],
#        [ 44829,      0,      3],
#        [ 46227,      0,      5],
#        [ 46812,      0,      2],
#        [ 47429,      0,      3],
#        [ 49627,      0,      5],
#        [ 50187,      0,      2],
#        [ 50828,      0,      3],
#        [ 53027,      0,      4],
#        [ 53627,      0,      2],
#        [ 54229,      0,      3],
#        [ 56452,      0,      5],
#        [ 57372,      0,      2],
#        [ 57654,      0,      3],
#        [ 59682,      0,      1],
#        [ 60657,      0,      4],
#        [ 61196,      0,      1],
#        [ 61858,      0,      3],
#        [ 63257,      0,      4],
#        [ 64032,      0,      1],
#        [ 64458,      0,      3],
#        [ 65857,      0,      4],
#        [ 66621,      0,      1],
#        [ 67063,      0,      3],
#        [ 70061,      0,      4],
#        [ 70557,      0,      1],
#        [ 71263,      0,      3],
#        [ 73461,      0,      4],
#        [ 74366,      0,      2],
#        [ 74663,      0,      3],
#        [ 76066,      0,      4],
#        [ 76971,      0,      1],
#        [ 77268,      0,      3],
#        [ 80266,      0,      4],
#        [ 80831,      0,      1],
#        [ 81468,      0,      3],
#        [ 84466,      0,      5],
#        [ 85136,      0,      2],
#        [ 85668,      0,      3],
#        [ 87871,      0,      5],
#        [ 88546,      0,      2],
#        [ 89073,      0,      3],
#        [ 92081,      0,      5],
#        [ 92731,      0,      2],
#        [ 93288,      0,      3],
#        [ 96286,      0,      5],
#        [ 97071,      0,      2],
#        [ 97489,      0,      3],
#        [ 98891,      0,      4],
#        [ 99481,      0,      1],
#        [100093,      0,      3],
#        [102295,      0,      4],
#        [102885,      0,      1],
#        [103501,      0,      3]])

# %%
raw_triggers=[ev[0] for ev in raw_evs]

# %%
raw_triggers
# Out:
# [21816,
#  24018,
#  24672,
#  25218,
#  26617,
#  27222,
#  27819,
#  29217,
#  30007,
#  30425,
#  32627,
#  33232,
#  33829,
#  35228,
#  36123,
#  36429,
#  38292,
#  39427,
#  40207,
#  40629,
#  43627,
#  44417,
#  44829,
#  46227,
#  46812,
#  47429,
#  49627,
#  50187,
#  50828,
#  53027,
#  53627,
#  54229,
#  56452,
#  57372,
#  57654,
#  59682,
#  60657,
#  61196,
#  61858,
#  63257,
#  64032,
#  64458,
#  65857,
#  66621,
#  67063,
#  70061,
#  70557,
#  71263,
#  73461,
#  74366,
#  74663,
#  76066,
#  76971,
#  77268,
#  80266,
#  80831,
#  81468,
#  84466,
#  85136,
#  85668,
#  87871,
#  88546,
#  89073,
#  92081,
#  92731,
#  93288,
#  96286,
#  97071,
#  97489,
#  98891,
#  99481,
#  100093,
#  102295,
#  102885,
#  103501]

# %%
#a=mne.io.read_raw_egi(ROOT+'A00053440/EEG/raw/raw_format/A00053440_part2005.raw',montage=mne.channels.read_montage(kind='GSN-HydroCel-129'),preload=True, verbose=True)

# %%
#mne.find_events(a)

# %%
raw.filter(1,50).plot()

# %%
csv_evs[86]

# %%
raw2=mne.io.read_raw_egi(ROOT+'A00053440/EEG/raw/raw_format/A00053440_part2001.raw',montage=mne.channels.read_montage(kind='GSN-HydroCel-129'),preload=True, verbose=True)
raw2.info
# Out:
# Reading EGI header from /home/dcellier/RDSS/CMI_data/MIPDB/EEGData/A00053440/EEG/raw/raw_format/A00053440_part2001.raw...
#     Reading events ...
#     Assembling measurement info ...
#     Synthesizing trigger channel "STI 014" ...
#     Excluding events {103 , 105 , 106 , 4   , 83  , 85  , 86  , 95  , 96  , 97  } ...
# Reading 0 ... 103450  =      0.000 ...   206.900 secs...
# <ipython-input-22-955237a551be>:1: RuntimeWarning: The following EEG sensors did not have a position specified in the selected montage: ['E129']. Their position has been left untouched.
#   raw2=mne.io.read_raw_egi(ROOT+'A00053440/EEG/raw/raw_format/A00053440_part2001.raw',montage=mne.channels.read_montage(kind='GSN-HydroCel-129'),preload=True, verbose=True)
# <Info | 17 non-empty fields
#     bads : list | 0 items
#     ch_names : list | E1, E2, E3, E4, E5, E6, E7, E8, E9, ...
#     chs : list | 145 items (EEG: 129, STIM: 16)
#     comps : list | 0 items
#     custom_ref_applied : bool | False
#     dev_head_t : Transform | 3 items
#     dig : list | 131 items
#     events : list | 0 items
#     highpass : float | 0.0 Hz
#     hpi_meas : list | 0 items
#     hpi_results : list | 0 items
#     lowpass : float | 250.0 Hz
#     meas_date : tuple | 2014-08-25 16:59:33 GMT
#     nchan : int | 145
#     proc_history : list | 0 items
#     projs : list | 0 items
#     sfreq : float | 500.0 Hz
#     acq_pars : NoneType
#     acq_stim : NoneType
#     ctf_head_t : NoneType
#     description : NoneType
#     dev_ctf_t : NoneType
#     experimenter : NoneType
#     file_id : NoneType
#     gantry_angle : NoneType
#     hpi_subsystem : NoneType
#     kit_system_id : NoneType
#     line_freq : NoneType
#     meas_id : NoneType
#     proj_id : NoneType
#     proj_name : NoneType
#     subject_info : NoneType
#     xplotter_layout : NoneType
# >

# %%
raw2_evs=mne.find_events(raw2)
# Out:
# 75 events found
# Event IDs: [1 2 3 4 5]

# %%
raw2_evs
# Out:
# array([[ 18467,      0,      3],
#        [ 19871,      0,      5],
#        [ 20786,      0,      2],
#        [ 21071,      0,      3],
#        [ 22470,      0,      5],
#        [ 23350,      0,      2],
#        [ 23678,      0,      3],
#        [ 25825,      0,      1],
#        [ 25880,      0,      5],
#        [ 26790,      0,      2],
#        [ 27082,      0,      3],
#        [ 30090,      0,      5],
#        [ 30765,      0,      2],
#        [ 31292,      0,      3],
#        [ 32695,      0,      4],
#        [ 33110,      0,      1],
#        [ 33897,      0,      3],
#        [ 35295,      0,      5],
#        [ 36050,      0,      2],
#        [ 36498,      0,      3],
#        [ 38700,      0,      5],
#        [ 39481,      0,      2],
#        [ 39902,      0,      3],
#        [ 42105,      0,      4],
#        [ 42650,      0,      1],
#        [ 43327,      0,      3],
#        [ 45531,      0,      4],
#        [ 46264,      0,      1],
#        [ 46732,      0,      3],
#        [ 48934,      0,      5],
#        [ 49560,      0,      2],
#        [ 50137,      0,      3],
#        [ 53140,      0,      4],
#        [ 53880,      0,      1],
#        [ 54341,      0,      3],
#        [ 55744,      0,      4],
#        [ 56729,      0,      1],
#        [ 56948,      0,      3],
#        [ 59950,      0,      4],
#        [ 60644,      0,      1],
#        [ 61151,      0,      3],
#        [ 63355,      0,      4],
#        [ 64075,      0,      1],
#        [ 64557,      0,      3],
#        [ 65954,      0,      4],
#        [ 66734,      0,      1],
#        [ 67156,      0,      3],
#        [ 70159,      0,      4],
#        [ 70976,      0,      1],
#        [ 71361,      0,      3],
#        [ 73564,      0,      5],
#        [ 74364,      0,      2],
#        [ 74766,      0,      3],
#        [ 77769,      0,      5],
#        [ 78459,      0,      2],
#        [ 78971,      0,      3],
#        [ 81969,      0,      5],
#        [ 82534,      0,      2],
#        [ 83171,      0,      3],
#        [ 84568,      0,      4],
#        [ 85024,      0,      2],
#        [ 85584,      0,      1],
#        [ 85770,      0,      3],
#        [ 88768,      0,      4],
#        [ 89385,      0,      1],
#        [ 89970,      0,      3],
#        [ 92173,      0,      4],
#        [ 92773,      0,      1],
#        [ 93375,      0,      3],
#        [ 94773,      0,      5],
#        [ 95563,      0,      2],
#        [ 95981,      0,      3],
#        [ 98988,      0,      5],
#        [ 99623,      0,      2],
#        [100189,      0,      3]])

# %%
#all_sub_events['A00053440']

# %%
for b in all_sub_events['A00053440']:
    print(1)
    for a in b:
        print(a.split('_events'))
# Out:
# 1
# ['A00053440005', '.csv']
# 1
# ['A00053440_part2001', '.csv']
# 1
# ['A00053440_part2003', '.csv']

# %% [markdown]
# 94 = Start Contrast Change Paradigm Block 1;
#
# 95 = Start Contrast Change Paradigm Block 2;
#
# 96 = Start Contrast Change Paradigm Block 3;
#
# 5 = start trial; (start of ITI) -lasts for 2.8,4.4,6
#
# 8 = Target ON left; (start change) -lasts for 2.4 seconds
#
# 9 = Target ON right; (start change)
#
# 12 = button press left;
#
# 13 = button press right;

# %%
#[t[2] for t in y]

# %%
for sub in all_sub_events:
    sub_dict=all_sub_events[sub]
    if len(sub_dict)<3:
        print(sub)
# Out:
# A00055628
# A00062919
# A00063051
# A00063117
# A00053990
# A00054023
# A00054359
# A00055103
# A00055296
# A00056116
# A00056604
# A00056693
# A00056913
# A00058775

# %%
raw2
# Out:
# <RawEGI  |  A00053440_part2001.raw, n_channels x n_times : 145 x 103451 (206.9 sec), ~114.8 MB, data loaded>

# %%
y=all_sub_events['A00059578'][0]['A00059578004_events.csv']#.keys()
y
# Out:
# [[5172, 0, 94],
#  [9200, 0, 5],
#  [15090, 0, 8],
#  [15625, 0, 12],
#  [16290, 0, 5],
#  [17689, 0, 8],
#  [18345, 0, 12],
#  [18890, 0, 5],
#  [20289, 0, 9],
#  [20915, 0, 13],
#  [21490, 0, 5],
#  [22890, 0, 8],
#  [23220, 0, 12],
#  [24090, 0, 5],
#  [27090, 0, 8],
#  [27605, 0, 13],
#  [28290, 0, 5],
#  [29005, 0, 12],
#  [29690, 0, 9],
#  [30335, 0, 13],
#  [30890, 0, 5],
#  [33090, 0, 9],
#  [33875, 0, 13],
#  [34290, 0, 5],
#  [35690, 0, 8],
#  [36105, 0, 12],
#  [36890, 0, 5],
#  [39890, 0, 9],
#  [40465, 0, 13],
#  [41090, 0, 5],
#  [43290, 0, 9],
#  [44095, 0, 13],
#  [44490, 0, 5],
#  [47490, 0, 8],
#  [48150, 0, 12],
#  [48690, 0, 5],
#  [50090, 0, 9],
#  [50645, 0, 13],
#  [51290, 0, 5],
#  [54290, 0, 9],
#  [54890, 0, 13],
#  [55490, 0, 5],
#  [56890, 0, 8],
#  [57385, 0, 12],
#  [58090, 0, 5],
#  [60880, 0, 13],
#  [61090, 0, 9],
#  [62260, 0, 13],
#  [62290, 0, 5],
#  [64490, 0, 9],
#  [65045, 0, 13],
#  [65690, 0, 5],
#  [67890, 0, 9],
#  [68755, 0, 13],
#  [69090, 0, 5],
#  [71290, 0, 8],
#  [71750, 0, 12],
#  [72490, 0, 5],
#  [74690, 0, 8],
#  [75340, 0, 12],
#  [75890, 0, 5],
#  [78890, 0, 8],
#  [79280, 0, 12],
#  [80090, 0, 5],
#  [82290, 0, 8],
#  [82925, 0, 12],
#  [83490, 0, 5],
#  [86490, 0, 8],
#  [87125, 0, 12],
#  [87690, 0, 5],
#  [90690, 0, 9],
#  [91225, 0, 13],
#  [91890, 0, 5],
#  [93290, 0, 9],
#  [94490, 0, 5],
#  [94495, 0, 13]]

# %%
for s in x:
    print(s)
# Out:
# c

# %%
csv_events=pd.read_csv(ROOT+'A00059578/EEG/raw/csv_format/A00059578004_events.csv')
csv_evs=csv_events[csv_events.type !='type'].reset_index(drop=True)

# %%
csv_trigs=[int(n) for n in list(csv_evs.latency)[1:]]#==triggers
#csv_trigs==raw_triggers
csv_trigs
# Out:
# [9200,
#  15090,
#  15625,
#  16290,
#  17689,
#  18345,
#  18890,
#  20289,
#  20915,
#  21490,
#  22890,
#  23220,
#  24090,
#  27090,
#  27605,
#  28290,
#  29005,
#  29690,
#  30335,
#  30890,
#  33090,
#  33875,
#  34290,
#  35690,
#  36105,
#  36890,
#  39890,
#  40465,
#  41090,
#  43290,
#  44095,
#  44490,
#  47490,
#  48150,
#  48690,
#  50090,
#  50645,
#  51290,
#  54290,
#  54890,
#  55490,
#  56890,
#  57385,
#  58090,
#  60880,
#  61090,
#  62260,
#  62290,
#  64490,
#  65045,
#  65690,
#  67890,
#  68755,
#  69090,
#  71290,
#  71750,
#  72490,
#  74690,
#  75340,
#  75890,
#  78890,
#  79280,
#  80090,
#  82290,
#  82925,
#  83490,
#  86490,
#  87125,
#  87690,
#  90690,
#  91225,
#  91890,
#  93290,
#  94490,
#  94495]

# %%
#csv_trigs
csv_codes=[int(ev) for ev in csv_evs.type[1:]]
csv_iterable=list(zip(csv_codes,csv_trigs))
print([a for a in csv_iterable])
# Out:
# [(5, 9200), (8, 15090), (12, 15625), (5, 16290), (8, 17689), (12, 18345), (5, 18890), (9, 20289), (13, 20915), (5, 21490), (8, 22890), (12, 23220), (5, 24090), (8, 27090), (13, 27605), (5, 28290), (12, 29005), (9, 29690), (13, 30335), (5, 30890), (9, 33090), (13, 33875), (5, 34290), (8, 35690), (12, 36105), (5, 36890), (9, 39890), (13, 40465), (5, 41090), (9, 43290), (13, 44095), (5, 44490), (8, 47490), (12, 48150), (5, 48690), (9, 50090), (13, 50645), (5, 51290), (9, 54290), (13, 54890), (5, 55490), (8, 56890), (12, 57385), (5, 58090), (13, 60880), (9, 61090), (13, 62260), (5, 62290), (9, 64490), (13, 65045), (5, 65690), (9, 67890), (13, 68755), (5, 69090), (8, 71290), (12, 71750), (5, 72490), (8, 74690), (12, 75340), (5, 75890), (8, 78890), (12, 79280), (5, 80090), (8, 82290), (12, 82925), (5, 83490), (8, 86490), (12, 87125), (5, 87690), (9, 90690), (13, 91225), (5, 91890), (9, 93290), (5, 94490), (13, 94495)]

# %%
new_csv_iterable=csv_iterable.copy()
for n in range(1,len(csv_iterable)): #need to get the RT of each button press
    thisCode=csv_iterable[n][0]
    thisTrig=csv_iterable[n][1]
    prevCode=csv_iterable[n-1][0]
    #prevTrig=csv_iterable[n-1][1]
    tossTrial_resp=0
    tossTrial_no_resp=0
    if prevCode==5 and (thisCode==12 or thisCode==13):
        tossTrial_resp=1     
    if tossTrial_resp:
        k=n
        print(k)
        print(len(csv_iterable))
        if (k+2 < len(csv_iterable)): #if this hasn't reached the end
            nextCode=csv_iterable[k+1][0]
            while nextCode != 5:
                k=k+1
                nextCode=csv_iterable[k+1][0]
        trials_to_toss=csv_iterable[n-1:k+1]
        print(trials_to_toss)
        for trial in trials_to_toss:
            new_csv_iterable.remove(trial)
csv_iterable=new_csv_iterable
# Out:
# 16
# 75
# [(5, 28290), (12, 29005), (9, 29690), (13, 30335)]
# 44
# 75
# [(5, 58090), (13, 60880), (9, 61090), (13, 62260)]
# 74
# 75
# [(5, 94490), (13, 94495)]

# %%
print([a for a in csv_iterable])
# Out:
# [(5, 9200), (8, 15090), (12, 15625), (5, 16290), (8, 17689), (12, 18345), (5, 18890), (9, 20289), (13, 20915), (5, 21490), (8, 22890), (12, 23220), (5, 24090), (8, 27090), (13, 27605), (5, 30890), (9, 33090), (13, 33875), (5, 34290), (8, 35690), (12, 36105), (5, 36890), (9, 39890), (13, 40465), (5, 41090), (9, 43290), (13, 44095), (5, 44490), (8, 47490), (12, 48150), (5, 48690), (9, 50090), (13, 50645), (5, 51290), (9, 54290), (13, 54890), (5, 55490), (8, 56890), (12, 57385), (5, 62290), (9, 64490), (13, 65045), (5, 65690), (9, 67890), (13, 68755), (5, 69090), (8, 71290), (12, 71750), (5, 72490), (8, 74690), (12, 75340), (5, 75890), (8, 78890), (12, 79280), (5, 80090), (8, 82290), (12, 82925), (5, 83490), (8, 86490), (12, 87125), (5, 87690), (9, 90690), (13, 91225), (5, 91890), (9, 93290)]

# %%
new_csv_iterable=csv_iterable.copy()
for n in range(len(csv_iterable)-1): #need to get the RT of each button press
    thisCode=csv_iterable[n][0]
    thisTrig=csv_iterable[n][1]
    nextCode=csv_iterable[n+1][0]
    tossTrial_no_resp=0
    if (thisCode==9 or thisCode==8) and nextCode==5:
        tossTrial_no_resp=1  
    if tossTrial_no_resp:
        k=n
        print(k)
        print(len(csv_iterable))
        if (k+2 < len(csv_iterable)): #if this hasn't reached the end
            nextCode=csv_iterable[k+1][0]
            while nextCode != 5:
                k=k+1
                nextCode=csv_iterable[k+1][0]
        trials_to_toss=csv_iterable[n-1:k+1]
        print(trials_to_toss)
        for trial in trials_to_toss:
            new_csv_iterable.remove(trial)

# %%
print([a for a in new_csv_iterable])
# Out:
# [(5, 9200), (8, 15090), (12, 15625), (5, 16290), (8, 17689), (12, 18345), (5, 18890), (9, 20289), (13, 20915), (5, 21490), (8, 22890), (12, 23220), (5, 24090), (8, 27090), (13, 27605), (5, 30890), (9, 33090), (13, 33875), (5, 34290), (8, 35690), (12, 36105), (5, 36890), (9, 39890), (13, 40465), (5, 41090), (9, 43290), (13, 44095), (5, 44490), (8, 47490), (12, 48150), (5, 48690), (9, 50090), (13, 50645), (5, 51290), (9, 54290), (13, 54890), (5, 55490), (8, 56890), (12, 57385), (5, 62290), (9, 64490), (13, 65045), (5, 65690), (9, 67890), (13, 68755), (5, 69090), (8, 71290), (12, 71750), (5, 72490), (8, 74690), (12, 75340), (5, 75890), (8, 78890), (12, 79280), (5, 80090), (8, 82290), (12, 82925), (5, 83490), (8, 86490), (12, 87125), (5, 87690), (9, 90690), (13, 91225), (5, 91890), (9, 93290)]

# %%
new_csv_iterable2=new_csv_iterable.copy()
g=[a for a in new_csv_iterable[-3:]]
if (g[2][0] != 12) or (g[2][0] != 13):
    print(g[2][0])
if (g[1][0] != 8) or (g[1][0] != 9):
# Out:
# 9

# %%
a=[1,3,4,5,6,7]
a.remove(3)
a
# Out:
# [1, 4, 5, 6, 7]

# %%
print([a for a in new_csv_iterable])
# Out:
# [(5, 21816), (8, 24018), (12, 24672), (5, 25218), (9, 26617), (13, 27222), (5, 27819), (9, 29217), (13, 30007), (5, 30425), (9, 32627), (13, 33232), (5, 33829), (9, 35228), (13, 36123), (5, 40629), (8, 43627), (12, 44417), (5, 44829), (9, 46227), (13, 46812), (5, 47429), (9, 49627), (13, 50187), (5, 50828), (8, 53027), (13, 53627), (5, 54229), (9, 56452), (13, 57372), (5, 61858), (8, 63257), (12, 64032), (5, 64458), (8, 65857), (12, 66621), (5, 67063), (8, 70061), (12, 70557), (5, 71263), (8, 73461), (13, 74366), (5, 74663), (8, 76066), (12, 76971), (5, 77268), (8, 80266), (12, 80831), (5, 81468), (9, 84466), (13, 85136), (5, 85668), (9, 87871), (13, 88546), (5, 89073), (9, 92081), (13, 92731), (5, 93288), (9, 96286), (13, 97071), (5, 97489), (8, 98891), (12, 99481), (5, 100093), (8, 102295), (12, 102885), (5, 103501)]

# %%
new_csv_events=[]
for ev in new_csv_iterable:
    new_csv_events.append([ev[0],0,ev[1]])

# %%
new_csv_events
# Out:
# [[5, 0, 21816],
#  [8, 0, 24018],
#  [12, 0, 24672],
#  [5, 0, 25218],
#  [9, 0, 26617],
#  [13, 0, 27222],
#  [5, 0, 27819],
#  [9, 0, 29217],
#  [13, 0, 30007],
#  [5, 0, 30425],
#  [9, 0, 32627],
#  [13, 0, 33232],
#  [5, 0, 33829],
#  [9, 0, 35228],
#  [13, 0, 36123],
#  [5, 0, 40629],
#  [8, 0, 43627],
#  [12, 0, 44417],
#  [5, 0, 44829],
#  [9, 0, 46227],
#  [13, 0, 46812],
#  [5, 0, 47429],
#  [9, 0, 49627],
#  [13, 0, 50187],
#  [5, 0, 50828],
#  [8, 0, 53027],
#  [13, 0, 53627],
#  [5, 0, 54229],
#  [9, 0, 56452],
#  [13, 0, 57372],
#  [5, 0, 61858],
#  [8, 0, 63257],
#  [12, 0, 64032],
#  [5, 0, 64458],
#  [8, 0, 65857],
#  [12, 0, 66621],
#  [5, 0, 67063],
#  [8, 0, 70061],
#  [12, 0, 70557],
#  [5, 0, 71263],
#  [8, 0, 73461],
#  [13, 0, 74366],
#  [5, 0, 74663],
#  [8, 0, 76066],
#  [12, 0, 76971],
#  [5, 0, 77268],
#  [8, 0, 80266],
#  [12, 0, 80831],
#  [5, 0, 81468],
#  [9, 0, 84466],
#  [13, 0, 85136],
#  [5, 0, 85668],
#  [9, 0, 87871],
#  [13, 0, 88546],
#  [5, 0, 89073],
#  [9, 0, 92081],
#  [13, 0, 92731],
#  [5, 0, 93288],
#  [9, 0, 96286],
#  [13, 0, 97071],
#  [5, 0, 97489],
#  [8, 0, 98891],
#  [12, 0, 99481],
#  [5, 0, 100093],
#  [8, 0, 102295],
#  [12, 0, 102885],
#  [5, 0, 103501]]
